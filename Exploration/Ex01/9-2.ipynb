# %%
import pandas as pd
from sklearn.linear_model import LinearRegression 

# (1) 데이터 가져오기
# CSV 파일 경로
file_path = '~/data/data/bike-sharing-demand/train.csv'

# CSV 파일을 DataFrame으로 읽어옴
train = pd.read_csv(file_path)

# 데이터 확인 
print(train.head())
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# (2) datetime 컬럼을 datetime 자료형으로 변환하고 연, 월, 일, 시, 분, 초까지 6가지 컬럼 생성하기
# datetime 컬럼을 datetime 자료형으로 변환

train['datetime'] = pd.to_datetime(train['datetime'])

# 연, 월, 일, 시, 분, 초 컬럼 생성
train['year'] = train['datetime'].dt.year
train['month'] = train['datetime'].dt.month
train['day'] = train['datetime'].dt.day
train['hour'] = train['datetime'].dt.hour
train['minute'] = train['datetime'].dt.minute
train['second'] = train['datetime'].dt.second

# %%
# (3) year, month, day, hour, minute, second 데이터 개수 시각화하기

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 12))

# Year subplot
plt.subplot(2, 3, 1)
sns.countplot(data=train, x='year')
plt.title('Year Count')

# Month subplot
plt.subplot(2, 3, 2)
sns.countplot(data=train, x='month')
plt.title('Month Count')

# Day subplot
plt.subplot(2, 3, 3)
sns.countplot(data=train, x='day')
plt.title('Day Count')

# Hour subplot
plt.subplot(2, 3, 4)
sns.countplot(data=train, x='hour')
plt.title('Hour Count')

# Minute subplot
plt.subplot(2, 3, 5)
sns.countplot(data=train, x='minute')
plt.title('Minute Count')

# Second subplot
plt.subplot(2, 3, 6)
sns.countplot(data=train, x='second')
plt.title('Second Count')

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %%
# (4)  X, y 컬럼 선택 및 train/test 데이터 분리
from sklearn.model_selection import train_test_split

features = ['season', 'holiday', 'workingday', 'weather', 'temp', 'humidity', 'windspeed', 'year', 'month', 'hour']
['year', 'month', '']

# Feature X와 Target y 정의
X = train[features]
y = train['count']

X_train,X_test, y_train, y_test = train_test_split(X, y, 0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_62/2088487273.py in <module>
#       9 y = train['count']
#      10
# ---> 11 X_train,X_test, y_train, y_test = train_test_split(X, y, 0.2)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2417         raise ValueError("At least one array required as input")
#    2418
# -> 2419     arrays = indexable(*arrays)
#    2420
#    2421     n_samples = _num_samples(arrays[0])
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     368     """
#     369     result = [_make_indexable(X) for X in iterables]
# --> 370     check_consistent_length(*result)
#     371     return result
#     372
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     326     """
#     327
# --> 328     lengths = [_num_samples(X) for X in arrays if X is not None]
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     326     """
#     327
# --> 328     lengths = [_num_samples(X) for X in arrays if X is not None]
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     266     if hasattr(x, "shape") and x.shape is not None:
#     267         if len(x.shape) == 0:
# --> 268             raise TypeError(
#     269                 "Singleton array %r cannot be considered a valid collection." % x
#     270             )
#
# TypeError: Singleton array array(0.2) cannot be considered a valid collection.

# %%
# (5) Linear Regression 모델 학습

model = LinearRegression()
